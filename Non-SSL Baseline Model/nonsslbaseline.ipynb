# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import random
from torch.utils.data import DataLoader, random_split, Subset
from torchvision.models import resnet50, resnet34, resnet18
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedShuffleSplit , StratifiedKFold
import numpy as np
import matplotlib.pyplot as plt

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set the random seed for reproducibility
set_seed(42)

# %% [markdown]
# # Generating input data for training

# %% [markdown]
# While running on Kaggle, turn on internet in session options to download data.

# %%
# Data augmentation and normalization for training
# Just normalization for validation
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_train)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#Stratified split
trainset_targets = trainset.targets
# Define StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
# Split the dataset into training and validation sets
unused_idx, used_idx = next(sss.split(trainset.data, trainset_targets))
unused_subset = Subset(trainset, unused_idx)
used_subset = Subset(trainset, used_idx)
print(len(unused_subset))
print(len(used_subset))

# Prepare targets for used_subset
used_targets = [trainset_targets[i] for i in used_idx]
# Second split: 80% (train) and 20% (validation) of used_subset
sssplit = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, val_idx = next(sssplit.split(used_idx, used_targets))
train_data = Subset(trainset, [used_idx[i] for i in train_idx])
val_data = Subset(trainset, [used_idx[i] for i in val_idx])
print(len(train_data))
print(len(val_data))
# Out:
# 35000
# 15000
# 12000
# 3000

# %%
train_loader = DataLoader(train_data, batch_size=256, shuffle=True)
num_batches = len(train_loader)
print(num_batches)
# Out:
# 47

# %%
# load validation data
val_loader = DataLoader(val_data, batch_size=256, shuffle=False)

# %% [markdown]
# # Supervised Learning

# %% [markdown]
# 1 fold

# %% [markdown]
# Defining Model

# %%
# Load ResNet-50 without weights
baseline_model = resnet18(pretrained=False, num_classes=10)
# Replace the first 7x7 Conv with 3x3 Conv of stride 1
baseline_model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
# Remove the first MaxPooling2D layer (MaxPool2d)
baseline_model.maxpool = nn.Identity()  # Replace the first MaxPooling2D with an identity function
# Print model architecture
#print(baseline_model)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
baseline_model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): Identity()
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()  # CrossEntropyLoss for multi-class classification

# %%
optimizer = optim.Adam(baseline_model.parameters(), lr=0.0008)
# ExponentialLR scheduler for learning rate decay
exp_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# %%
num_epochs = 20
switch_epoch = 15
for epoch in range(num_epochs):
    for param_group in optimizer.param_groups:
        print(f'Start of Epoch {epoch+1}/{num_epochs}, Learning Rate: {param_group["lr"]:.6f}')
    baseline_model.train()  # Set the model to training mode
    running_loss = 0.0  # Initialize running loss, it is used to accumulate the total loss of all elements in a epoch
    counter = 1
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        # Forward pass
        outputs = baseline_model(inputs) #Compute predicted outputs by passing inputs to the model
        loss = criterion(outputs, labels) #Calculate the loss
      
        # Backward pass and optimization
        optimizer.zero_grad()   # Step 1: Clear old gradients
        loss.backward()         # Step 2: Compute new gradients, i.e Backward pass: Compute gradient of the loss with respect to model parameters
        optimizer.step()        # Step 3: Update model parameters
        running_loss += loss.item() * inputs.size(0)  # Accumulate loss. loss.item gives the avg loss of batch extrated from the loss tensor, input.size(0) gives the batch size, so * gives total loss in a batch
        #if counter % 10 == 0:
        #    print(f"Epoch [{epoch + 1}/{num_epochs}], Batch [{counter}/{num_batches}], Loss: {loss.item():.4f}")
        counter += 1

    epoch_loss = running_loss / len(train_loader.dataset)  # Running loss has total loss in an epoch, divide it by epoch size gives average loss in an epoch
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}")
    # validate the model
    baseline_model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = baseline_model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        accuracy = 100 * correct / total
    print(f'Accuracy of the model on the 3000 validation images: {accuracy:.2f}%')
    
    #Training accuracy
    baseline_model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = baseline_model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        accuracy = 100 * correct / total
    print(f'Accuracy of the model on the 12000 train images: {accuracy:.2f}%')    
  
    if epoch+1 >= switch_epoch:
        exp_scheduler.gamma =  0.6   #10.0/(epoch+1) #
    exp_scheduler.step()  # Update learning rate scheduler
    #step_scheduler.step()
# Out:
# Start of Epoch 1/20, Learning Rate: 0.000800
# Epoch 1/20, Loss: 1.8831
# Accuracy of the model on the 3000 validation images: 38.50%
# Accuracy of the model on the 12000 train images: 37.67%
# Start of Epoch 2/20, Learning Rate: 0.000720
# Epoch 2/20, Loss: 1.5463
# Accuracy of the model on the 3000 validation images: 42.67%
# Accuracy of the model on the 12000 train images: 44.27%
# Start of Epoch 3/20, Learning Rate: 0.000648
# Epoch 3/20, Loss: 1.3670
# Accuracy of the model on the 3000 validation images: 46.53%
# Accuracy of the model on the 12000 train images: 48.34%
# Start of Epoch 4/20, Learning Rate: 0.000583
# Epoch 4/20, Loss: 1.2302
# Accuracy of the model on the 3000 validation images: 52.40%
# Accuracy of the model on the 12000 train images: 56.05%
# Start of Epoch 5/20, Learning Rate: 0.000525
# Epoch 5/20, Loss: 1.1099
# Accuracy of the model on the 3000 validation images: 55.77%
# Accuracy of the model on the 12000 train images: 59.57%
# Start of Epoch 6/20, Learning Rate: 0.000472
# Epoch 6/20, Loss: 1.0227
# Accuracy of the model on the 3000 validation images: 58.93%
# Accuracy of the model on the 12000 train images: 62.71%
# Start of Epoch 7/20, Learning Rate: 0.000425
# Epoch 7/20, Loss: 0.9622
# Accuracy of the model on the 3000 validation images: 59.50%
# Accuracy of the model on the 12000 train images: 64.36%
# Start of Epoch 8/20, Learning Rate: 0.000383
# Epoch 8/20, Loss: 0.8830
# Accuracy of the model on the 3000 validation images: 61.73%
# Accuracy of the model on the 12000 train images: 67.67%
# Start of Epoch 9/20, Learning Rate: 0.000344
# Epoch 9/20, Loss: 0.8291
# Accuracy of the model on the 3000 validation images: 64.10%
# Accuracy of the model on the 12000 train images: 68.82%
# Start of Epoch 10/20, Learning Rate: 0.000310
# Epoch 10/20, Loss: 0.7715
# Accuracy of the model on the 3000 validation images: 65.70%
# Accuracy of the model on the 12000 train images: 71.97%
# Start of Epoch 11/20, Learning Rate: 0.000279
# Epoch 11/20, Loss: 0.7349
# Accuracy of the model on the 3000 validation images: 61.03%
# Accuracy of the model on the 12000 train images: 66.99%
# Start of Epoch 12/20, Learning Rate: 0.000251
# Epoch 12/20, Loss: 0.6986
# Accuracy of the model on the 3000 validation images: 67.03%
# Accuracy of the model on the 12000 train images: 74.32%
# Start of Epoch 13/20, Learning Rate: 0.000226
# Epoch 13/20, Loss: 0.6622
# Accuracy of the model on the 3000 validation images: 69.70%
# Accuracy of the model on the 12000 train images: 75.78%
# Start of Epoch 14/20, Learning Rate: 0.000203
# Epoch 14/20, Loss: 0.6183
# Accuracy of the model on the 3000 validation images: 69.70%
# Accuracy of the model on the 12000 train images: 77.61%
# Start of Epoch 15/20, Learning Rate: 0.000183
# Epoch 15/20, Loss: 0.5838
# Accuracy of the model on the 3000 validation images: 70.53%
# Accuracy of the model on the 12000 train images: 78.36%
# Start of Epoch 16/20, Learning Rate: 0.000110
# Epoch 16/20, Loss: 0.5456
# Accuracy of the model on the 3000 validation images: 73.13%
# Accuracy of the model on the 12000 train images: 82.02%
# Start of Epoch 17/20, Learning Rate: 0.000066
# Epoch 17/20, Loss: 0.5028
# Accuracy of the model on the 3000 validation images: 73.33%
# Accuracy of the model on the 12000 train images: 83.24%
# Start of Epoch 18/20, Learning Rate: 0.000040
# Epoch 18/20, Loss: 0.4805
# Accuracy of the model on the 3000 validation images: 73.27%
# Accuracy of the model on the 12000 train images: 84.01%
# Start of Epoch 19/20, Learning Rate: 0.000024
# Epoch 19/20, Loss: 0.4687
# Accuracy of the model on the 3000 validation images: 74.10%
# Accuracy of the model on the 12000 train images: 84.36%
# Start of Epoch 20/20, Learning Rate: 0.000014
# Epoch 20/20, Loss: 0.4507
# Accuracy of the model on the 3000 validation images: 74.63%
# Accuracy of the model on the 12000 train images: 84.41%

# %% [markdown]
# 5 fold cross validation

# %%
trainset_targets = trainset.targets
# Stratified split to get 30% of the data
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
_, used_idx = next(sss.split(trainset.data, trainset_targets))
used_subset = Subset(trainset, used_idx)

# Prepare targets for used_subset
used_targets = [trainset_targets[i] for i in used_idx]

# Stratified K-Fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
Loss = torch.zeros(5, 20)
Validation_accuracy = torch.zeros(5, 20)
Train_accuracy = torch.zeros(5, 20)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
for fold, (train_idx, val_idx) in enumerate(kf.split(np.zeros(len(used_targets)), used_targets)):
    print(f'Fold {fold + 1}')
    train_data = Subset(used_subset, train_idx)
    val_data = Subset(used_subset, val_idx)

    train_loader = DataLoader(train_data, batch_size=256, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=256, shuffle=False)

    # Load ResNet-18 without pretrained weights
    model = resnet18(pretrained=False, num_classes=10)
    model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    model.maxpool = nn.Identity()
    model.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0008)
    exp_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

    # Training
    num_epochs = 20
    switch_epoch = 15
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            
        epoch_loss = running_loss / len(train_loader.dataset)
        Loss[fold, epoch] = epoch_loss
        print(f'Epoch {epoch + 1}/{num_epochs}, Loss: {epoch_loss:.4f}')

        # Validation Accuracy
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            
        val_accuracy = 100 * correct / total
        Validation_accuracy[fold, epoch] = val_accuracy
        print(f'Validation Accuracy on fold {fold + 1}, Epoch {epoch + 1}/{num_epochs}: {val_accuracy:.2f}%')
        
        # Training Accuracy
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in train_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            
        Tr_accuracy = 100 * correct / total
        Train_accuracy[fold, epoch] = Tr_accuracy
        print(f'Training Accuracy on fold {fold + 1}, Epoch {epoch + 1}/{num_epochs}: {Tr_accuracy:.2f}%')
        
        if epoch + 1 >= switch_epoch:
            exp_scheduler.gamma = 0.6
        exp_scheduler.step()
        

# Calculate the mean along dim=0
average_loss = Loss.mean(dim=0)
average_validation_accuracy = Validation_accuracy.mean(dim=0)
average_train_accuracy = Train_accuracy.mean(dim=0)
# Out:
# Fold 1
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1/20, Loss: 1.8695
# Validation Accuracy on fold 1, Epoch 1/20: 32.97%
# Training Accuracy on fold 1, Epoch 1/20: 33.08%
# Epoch 2/20, Loss: 1.5387
# Validation Accuracy on fold 1, Epoch 2/20: 39.87%
# Training Accuracy on fold 1, Epoch 2/20: 41.48%
# Epoch 3/20, Loss: 1.3708
# Validation Accuracy on fold 1, Epoch 3/20: 50.37%
# Training Accuracy on fold 1, Epoch 3/20: 50.72%
# Epoch 4/20, Loss: 1.2357
# Validation Accuracy on fold 1, Epoch 4/20: 51.20%
# Training Accuracy on fold 1, Epoch 4/20: 52.05%
# Epoch 5/20, Loss: 1.1100
# Validation Accuracy on fold 1, Epoch 5/20: 57.03%
# Training Accuracy on fold 1, Epoch 5/20: 58.67%
# Epoch 6/20, Loss: 1.0301
# Validation Accuracy on fold 1, Epoch 6/20: 59.87%
# Training Accuracy on fold 1, Epoch 6/20: 60.68%
# Epoch 7/20, Loss: 0.9524
# Validation Accuracy on fold 1, Epoch 7/20: 61.70%
# Training Accuracy on fold 1, Epoch 7/20: 63.61%
# Epoch 8/20, Loss: 0.8897
# Validation Accuracy on fold 1, Epoch 8/20: 66.40%
# Training Accuracy on fold 1, Epoch 8/20: 68.62%
# Epoch 9/20, Loss: 0.8132
# Validation Accuracy on fold 1, Epoch 9/20: 67.53%
# Training Accuracy on fold 1, Epoch 9/20: 70.62%
# Epoch 10/20, Loss: 0.7841
# Validation Accuracy on fold 1, Epoch 10/20: 70.33%
# Training Accuracy on fold 1, Epoch 10/20: 73.62%
# Epoch 11/20, Loss: 0.7206
# Validation Accuracy on fold 1, Epoch 11/20: 69.67%
# Training Accuracy on fold 1, Epoch 11/20: 73.33%
# Epoch 12/20, Loss: 0.6850
# Validation Accuracy on fold 1, Epoch 12/20: 70.67%
# Training Accuracy on fold 1, Epoch 12/20: 74.97%
# Epoch 13/20, Loss: 0.6667
# Validation Accuracy on fold 1, Epoch 13/20: 72.50%
# Training Accuracy on fold 1, Epoch 13/20: 76.07%
# Epoch 14/20, Loss: 0.6184
# Validation Accuracy on fold 1, Epoch 14/20: 70.87%
# Training Accuracy on fold 1, Epoch 14/20: 75.43%
# Epoch 15/20, Loss: 0.5942
# Validation Accuracy on fold 1, Epoch 15/20: 75.30%
# Training Accuracy on fold 1, Epoch 15/20: 79.57%
# Epoch 16/20, Loss: 0.5447
# Validation Accuracy on fold 1, Epoch 16/20: 75.93%
# Training Accuracy on fold 1, Epoch 16/20: 81.71%
# Epoch 17/20, Loss: 0.5085
# Validation Accuracy on fold 1, Epoch 17/20: 76.83%
# Training Accuracy on fold 1, Epoch 17/20: 83.01%
# Epoch 18/20, Loss: 0.4895
# Validation Accuracy on fold 1, Epoch 18/20: 76.80%
# Training Accuracy on fold 1, Epoch 18/20: 83.77%
# Epoch 19/20, Loss: 0.4709
# Validation Accuracy on fold 1, Epoch 19/20: 77.13%
# Training Accuracy on fold 1, Epoch 19/20: 84.22%
# Epoch 20/20, Loss: 0.4614
# Validation Accuracy on fold 1, Epoch 20/20: 77.43%
# Training Accuracy on fold 1, Epoch 20/20: 84.29%
# Fold 2
# Epoch 1/20, Loss: 1.9013
# Validation Accuracy on fold 2, Epoch 1/20: 33.50%
# Training Accuracy on fold 2, Epoch 1/20: 34.29%
# Epoch 2/20, Loss: 1.5724
# Validation Accuracy on fold 2, Epoch 2/20: 41.87%
# Training Accuracy on fold 2, Epoch 2/20: 43.91%
# Epoch 3/20, Loss: 1.4006
# Validation Accuracy on fold 2, Epoch 3/20: 45.70%
# Training Accuracy on fold 2, Epoch 3/20: 47.07%
# Epoch 4/20, Loss: 1.2569
# Validation Accuracy on fold 2, Epoch 4/20: 49.53%
# Training Accuracy on fold 2, Epoch 4/20: 51.35%
# Epoch 5/20, Loss: 1.1301
# Validation Accuracy on fold 2, Epoch 5/20: 54.67%
# Training Accuracy on fold 2, Epoch 5/20: 56.38%
# Epoch 6/20, Loss: 1.0448
# Validation Accuracy on fold 2, Epoch 6/20: 59.47%
# Training Accuracy on fold 2, Epoch 6/20: 61.62%
# Epoch 7/20, Loss: 0.9580
# Validation Accuracy on fold 2, Epoch 7/20: 61.73%
# Training Accuracy on fold 2, Epoch 7/20: 64.17%
# Epoch 8/20, Loss: 0.8808
# Validation Accuracy on fold 2, Epoch 8/20: 63.97%
# Training Accuracy on fold 2, Epoch 8/20: 67.89%
# Epoch 9/20, Loss: 0.8179
# Validation Accuracy on fold 2, Epoch 9/20: 65.50%
# Training Accuracy on fold 2, Epoch 9/20: 69.58%
# Epoch 10/20, Loss: 0.7801
# Validation Accuracy on fold 2, Epoch 10/20: 67.10%
# Training Accuracy on fold 2, Epoch 10/20: 72.12%
# Epoch 11/20, Loss: 0.7206
# Validation Accuracy on fold 2, Epoch 11/20: 69.47%
# Training Accuracy on fold 2, Epoch 11/20: 75.05%
# Epoch 12/20, Loss: 0.6781
# Validation Accuracy on fold 2, Epoch 12/20: 69.87%
# Training Accuracy on fold 2, Epoch 12/20: 74.92%
# Epoch 13/20, Loss: 0.6480
# Validation Accuracy on fold 2, Epoch 13/20: 69.77%
# Training Accuracy on fold 2, Epoch 13/20: 76.56%
# Epoch 14/20, Loss: 0.6121
# Validation Accuracy on fold 2, Epoch 14/20: 66.53%
# Training Accuracy on fold 2, Epoch 14/20: 71.93%
# Epoch 15/20, Loss: 0.5786
# Validation Accuracy on fold 2, Epoch 15/20: 71.47%
# Training Accuracy on fold 2, Epoch 15/20: 77.54%
# Epoch 16/20, Loss: 0.5428
# Validation Accuracy on fold 2, Epoch 16/20: 74.43%
# Training Accuracy on fold 2, Epoch 16/20: 81.48%
# Epoch 17/20, Loss: 0.5048
# Validation Accuracy on fold 2, Epoch 17/20: 75.00%
# Training Accuracy on fold 2, Epoch 17/20: 82.62%
# Epoch 18/20, Loss: 0.4703
# Validation Accuracy on fold 2, Epoch 18/20: 75.73%
# Training Accuracy on fold 2, Epoch 18/20: 84.25%
# Epoch 19/20, Loss: 0.4634
# Validation Accuracy on fold 2, Epoch 19/20: 76.23%
# Training Accuracy on fold 2, Epoch 19/20: 84.49%
# Epoch 20/20, Loss: 0.4585
# Validation Accuracy on fold 2, Epoch 20/20: 76.83%
# Training Accuracy on fold 2, Epoch 20/20: 84.54%
# Fold 3
# Epoch 1/20, Loss: 1.8844
# Validation Accuracy on fold 3, Epoch 1/20: 34.40%
# Training Accuracy on fold 3, Epoch 1/20: 36.05%
# Epoch 2/20, Loss: 1.5303
# Validation Accuracy on fold 3, Epoch 2/20: 44.50%
# Training Accuracy on fold 3, Epoch 2/20: 46.52%
# Epoch 3/20, Loss: 1.3604
# Validation Accuracy on fold 3, Epoch 3/20: 52.07%
# Training Accuracy on fold 3, Epoch 3/20: 53.75%
# Epoch 4/20, Loss: 1.2020
# Validation Accuracy on fold 3, Epoch 4/20: 53.10%
# Training Accuracy on fold 3, Epoch 4/20: 55.27%
# Epoch 5/20, Loss: 1.1003
# Validation Accuracy on fold 3, Epoch 5/20: 54.57%
# Training Accuracy on fold 3, Epoch 5/20: 56.77%
# Epoch 6/20, Loss: 1.0215
# Validation Accuracy on fold 3, Epoch 6/20: 60.50%
# Training Accuracy on fold 3, Epoch 6/20: 63.23%
# Epoch 7/20, Loss: 0.9428
# Validation Accuracy on fold 3, Epoch 7/20: 61.13%
# Training Accuracy on fold 3, Epoch 7/20: 64.70%
# Epoch 8/20, Loss: 0.8866
# Validation Accuracy on fold 3, Epoch 8/20: 60.67%
# Training Accuracy on fold 3, Epoch 8/20: 65.04%
# Epoch 9/20, Loss: 0.8365
# Validation Accuracy on fold 3, Epoch 9/20: 54.53%
# Training Accuracy on fold 3, Epoch 9/20: 58.22%
# Epoch 10/20, Loss: 0.7699
# Validation Accuracy on fold 3, Epoch 10/20: 68.57%
# Training Accuracy on fold 3, Epoch 10/20: 72.98%
# Epoch 11/20, Loss: 0.7301
# Validation Accuracy on fold 3, Epoch 11/20: 69.50%
# Training Accuracy on fold 3, Epoch 11/20: 74.22%
# Epoch 12/20, Loss: 0.7043
# Validation Accuracy on fold 3, Epoch 12/20: 70.93%
# Training Accuracy on fold 3, Epoch 12/20: 75.76%
# Epoch 13/20, Loss: 0.6640
# Validation Accuracy on fold 3, Epoch 13/20: 69.47%
# Training Accuracy on fold 3, Epoch 13/20: 74.31%
# Epoch 14/20, Loss: 0.6138
# Validation Accuracy on fold 3, Epoch 14/20: 72.27%
# Training Accuracy on fold 3, Epoch 14/20: 77.92%
# Epoch 15/20, Loss: 0.5978
# Validation Accuracy on fold 3, Epoch 15/20: 71.63%
# Training Accuracy on fold 3, Epoch 15/20: 78.88%
# Epoch 16/20, Loss: 0.5480
# Validation Accuracy on fold 3, Epoch 16/20: 75.87%
# Training Accuracy on fold 3, Epoch 16/20: 81.94%
# Epoch 17/20, Loss: 0.5095
# Validation Accuracy on fold 3, Epoch 17/20: 75.10%
# Training Accuracy on fold 3, Epoch 17/20: 82.60%
# Epoch 18/20, Loss: 0.4952
# Validation Accuracy on fold 3, Epoch 18/20: 75.90%
# Training Accuracy on fold 3, Epoch 18/20: 83.99%
# Epoch 19/20, Loss: 0.4757
# Validation Accuracy on fold 3, Epoch 19/20: 75.80%
# Training Accuracy on fold 3, Epoch 19/20: 84.68%
# Epoch 20/20, Loss: 0.4639
# Validation Accuracy on fold 3, Epoch 20/20: 76.50%
# Training Accuracy on fold 3, Epoch 20/20: 84.22%
# Fold 4
# Epoch 1/20, Loss: 1.9059
# Validation Accuracy on fold 4, Epoch 1/20: 33.90%
# Training Accuracy on fold 4, Epoch 1/20: 34.88%
# Epoch 2/20, Loss: 1.5465
# Validation Accuracy on fold 4, Epoch 2/20: 45.77%
# Training Accuracy on fold 4, Epoch 2/20: 44.96%
# Epoch 3/20, Loss: 1.3949
# Validation Accuracy on fold 4, Epoch 3/20: 52.33%
# Training Accuracy on fold 4, Epoch 3/20: 52.65%
# Epoch 4/20, Loss: 1.2475
# Validation Accuracy on fold 4, Epoch 4/20: 51.67%
# Training Accuracy on fold 4, Epoch 4/20: 52.94%
# Epoch 5/20, Loss: 1.1425
# Validation Accuracy on fold 4, Epoch 5/20: 59.87%
# Training Accuracy on fold 4, Epoch 5/20: 60.80%
# Epoch 6/20, Loss: 1.0499
# Validation Accuracy on fold 4, Epoch 6/20: 57.57%
# Training Accuracy on fold 4, Epoch 6/20: 59.56%
# Epoch 7/20, Loss: 0.9572
# Validation Accuracy on fold 4, Epoch 7/20: 62.27%
# Training Accuracy on fold 4, Epoch 7/20: 64.97%
# Epoch 8/20, Loss: 0.8912
# Validation Accuracy on fold 4, Epoch 8/20: 61.77%
# Training Accuracy on fold 4, Epoch 8/20: 64.41%
# Epoch 9/20, Loss: 0.8290
# Validation Accuracy on fold 4, Epoch 9/20: 67.33%
# Training Accuracy on fold 4, Epoch 9/20: 71.70%
# Epoch 10/20, Loss: 0.7797
# Validation Accuracy on fold 4, Epoch 10/20: 67.20%
# Training Accuracy on fold 4, Epoch 10/20: 71.39%
# Epoch 11/20, Loss: 0.7324
# Validation Accuracy on fold 4, Epoch 11/20: 62.57%
# Training Accuracy on fold 4, Epoch 11/20: 66.51%
# Epoch 12/20, Loss: 0.6938
# Validation Accuracy on fold 4, Epoch 12/20: 70.10%
# Training Accuracy on fold 4, Epoch 12/20: 74.02%
# Epoch 13/20, Loss: 0.6579
# Validation Accuracy on fold 4, Epoch 13/20: 71.90%
# Training Accuracy on fold 4, Epoch 13/20: 76.71%
# Epoch 14/20, Loss: 0.6210
# Validation Accuracy on fold 4, Epoch 14/20: 73.20%
# Training Accuracy on fold 4, Epoch 14/20: 77.04%
# Epoch 15/20, Loss: 0.5872
# Validation Accuracy on fold 4, Epoch 15/20: 73.43%
# Training Accuracy on fold 4, Epoch 15/20: 79.45%
# Epoch 16/20, Loss: 0.5427
# Validation Accuracy on fold 4, Epoch 16/20: 75.37%
# Training Accuracy on fold 4, Epoch 16/20: 81.81%
# Epoch 17/20, Loss: 0.5109
# Validation Accuracy on fold 4, Epoch 17/20: 75.83%
# Training Accuracy on fold 4, Epoch 17/20: 82.54%
# Epoch 18/20, Loss: 0.4870
# Validation Accuracy on fold 4, Epoch 18/20: 76.43%
# Training Accuracy on fold 4, Epoch 18/20: 83.62%
# Epoch 19/20, Loss: 0.4726
# Validation Accuracy on fold 4, Epoch 19/20: 77.10%
# Training Accuracy on fold 4, Epoch 19/20: 84.33%
# Epoch 20/20, Loss: 0.4682
# Validation Accuracy on fold 4, Epoch 20/20: 77.67%
# Training Accuracy on fold 4, Epoch 20/20: 84.83%
# Fold 5
# Epoch 1/20, Loss: 1.9127
# Validation Accuracy on fold 5, Epoch 1/20: 33.87%
# Training Accuracy on fold 5, Epoch 1/20: 35.69%
# Epoch 2/20, Loss: 1.5687
# Validation Accuracy on fold 5, Epoch 2/20: 41.97%
# Training Accuracy on fold 5, Epoch 2/20: 42.81%
# Epoch 3/20, Loss: 1.3892
# Validation Accuracy on fold 5, Epoch 3/20: 42.70%
# Training Accuracy on fold 5, Epoch 3/20: 45.31%
# Epoch 4/20, Loss: 1.2416
# Validation Accuracy on fold 5, Epoch 4/20: 52.77%
# Training Accuracy on fold 5, Epoch 4/20: 54.55%
# Epoch 5/20, Loss: 1.1171
# Validation Accuracy on fold 5, Epoch 5/20: 56.70%
# Training Accuracy on fold 5, Epoch 5/20: 59.18%
# Epoch 6/20, Loss: 1.0503
# Validation Accuracy on fold 5, Epoch 6/20: 61.00%
# Training Accuracy on fold 5, Epoch 6/20: 64.47%
# Epoch 7/20, Loss: 0.9522
# Validation Accuracy on fold 5, Epoch 7/20: 61.07%
# Training Accuracy on fold 5, Epoch 7/20: 66.18%
# Epoch 8/20, Loss: 0.8798
# Validation Accuracy on fold 5, Epoch 8/20: 63.77%
# Training Accuracy on fold 5, Epoch 8/20: 68.22%
# Epoch 9/20, Loss: 0.8289
# Validation Accuracy on fold 5, Epoch 9/20: 64.73%
# Training Accuracy on fold 5, Epoch 9/20: 68.88%
# Epoch 10/20, Loss: 0.7801
# Validation Accuracy on fold 5, Epoch 10/20: 67.40%
# Training Accuracy on fold 5, Epoch 10/20: 72.79%
# Epoch 11/20, Loss: 0.7190
# Validation Accuracy on fold 5, Epoch 11/20: 65.17%
# Training Accuracy on fold 5, Epoch 11/20: 71.09%
# Epoch 12/20, Loss: 0.6889
# Validation Accuracy on fold 5, Epoch 12/20: 69.27%
# Training Accuracy on fold 5, Epoch 12/20: 73.78%
# Epoch 13/20, Loss: 0.6470
# Validation Accuracy on fold 5, Epoch 13/20: 69.37%
# Training Accuracy on fold 5, Epoch 13/20: 76.42%
# Epoch 14/20, Loss: 0.6141
# Validation Accuracy on fold 5, Epoch 14/20: 68.50%
# Training Accuracy on fold 5, Epoch 14/20: 74.59%
# Epoch 15/20, Loss: 0.5851
# Validation Accuracy on fold 5, Epoch 15/20: 70.53%
# Training Accuracy on fold 5, Epoch 15/20: 77.50%
# Epoch 16/20, Loss: 0.5395
# Validation Accuracy on fold 5, Epoch 16/20: 74.53%
# Training Accuracy on fold 5, Epoch 16/20: 81.87%
# Epoch 17/20, Loss: 0.4989
# Validation Accuracy on fold 5, Epoch 17/20: 74.17%
# Training Accuracy on fold 5, Epoch 17/20: 82.81%
# Epoch 18/20, Loss: 0.4746
# Validation Accuracy on fold 5, Epoch 18/20: 74.93%
# Training Accuracy on fold 5, Epoch 18/20: 83.88%
# Epoch 19/20, Loss: 0.4649
# Validation Accuracy on fold 5, Epoch 19/20: 76.23%
# Training Accuracy on fold 5, Epoch 19/20: 84.36%
# Epoch 20/20, Loss: 0.4483
# Validation Accuracy on fold 5, Epoch 20/20: 76.07%
# Training Accuracy on fold 5, Epoch 20/20: 84.66%

# %% [markdown]
# printing the loss, val_acc and train_acc

# %%
print(f'avg loss = {average_loss}')
print(f'avg validation accuracy: {average_validation_accuracy}')
print(f'avg train accuracy = {average_train_accuracy}')
# Out:
# avg loss = tensor([1.8948, 1.5513, 1.3832, 1.2367, 1.1200, 1.0393, 0.9525, 0.8856, 0.8251,
#         0.7788, 0.7245, 0.6900, 0.6567, 0.6159, 0.5886, 0.5435, 0.5065, 0.4833,
#         0.4695, 0.4601])
# avg validation accuracy: tensor([33.7267, 42.7933, 48.6333, 51.6533, 56.5667, 59.6800, 61.5800, 63.3133,
#         63.9267, 68.1200, 67.2733, 70.1667, 70.6000, 70.2733, 72.4733, 75.2267,
#         75.3867, 75.9600, 76.5000, 76.9000])
# avg train accuracy = tensor([34.8000, 43.9350, 49.8983, 53.2333, 58.3617, 61.9133, 64.7267, 66.8367,
#         67.7983, 72.5817, 72.0383, 74.6900, 76.0117, 75.3833, 78.5883, 81.7617,
#         82.7167, 83.9000, 84.4183, 84.5100])

# %% [markdown]
# plotting the loss, val_acc and train_acc

# %%
# Epoch numbers from 1 to 20
epochs = list(range(1, 21))

# Create the figure and subplots
fig, axes = plt.subplots(3, 1, figsize=(10, 18))

# Plot Average Loss
axes[0].plot(epochs, average_loss, label='Average Loss', marker='o')
axes[0].set_title('Average Loss over Epochs')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Average Loss')
axes[0].legend()
axes[0].grid(True)  # Add grid

# Plot Validation Accuracy
axes[1].plot(epochs, average_validation_accuracy, label='Validation Accuracy', marker='o')
axes[1].set_title('Validation Accuracy over Epochs')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Validation Accuracy')
axes[1].legend()
axes[1].grid(True)  # Add grid

# Plot Training Accuracy
axes[2].plot(epochs, average_train_accuracy, label='Training Accuracy', marker='o')
axes[2].set_title('Training Accuracy over Epochs')
axes[2].set_xlabel('Epoch')
axes[2].set_ylabel('Training Accuracy')
axes[2].legend()
axes[2].grid(True)  # Add grid

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Test accuracy

# %%
# Use this
test_loader = DataLoader(testset, batch_size=256, shuffle=False)

# %%
# load 30% test data randomly
per70_data, per30_data = random_split(testset, [7000, 3000])
test_loader = DataLoader(per30_data, batch_size=256, shuffle=False)

# %%
#Stratified split
testset_targets = testset.targets
# Define StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
# Split the dataset into training and validation sets
unused_idx, used_idx = next(sss.split(testset.data, testset_targets))
unused_subset = Subset(testset, unused_idx)
used_subset = Subset(testset, used_idx)
print(len(unused_subset))
print(len(used_subset))
test_loader = DataLoader(used_subset, batch_size=256, shuffle=False)
# Out:
# 7000
# 3000

# %% [markdown]
# 1 fold test accuracy

# %%
baseline_model.eval()
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = baseline_model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the model on the 10000 test images: {accuracy:.2f}%')
# Out:
# Accuracy of the model on the 10000 test images: 76.12%

# %% [markdown]
# 5 fold test accuracy

# %%
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the model on the 10000 test images: {accuracy:.2f}%')
# Out:
# Accuracy of the model on the 10000 test images: 76.44%
