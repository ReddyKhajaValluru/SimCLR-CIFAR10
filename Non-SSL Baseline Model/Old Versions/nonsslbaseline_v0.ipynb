# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision import models
import random
from torch.utils.data import DataLoader, random_split, Subset
from torchvision.models import resnet50, resnet34, resnet18
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedShuffleSplit , StratifiedKFold
import numpy as np
import matplotlib.pyplot as plt

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set the random seed for reproducibility
set_seed(42)

# %% [markdown]
# # Generating input data for training

# %% [markdown]
# While running on Kaggle, turn on internet in session options to download data.

# %%
# Data augmentation and normalization for training
# Just normalization for validation
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)

testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
#Stratified split
trainset_targets = trainset.targets
# Define StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
# Split the dataset into training and validation sets
unused_idx, used_idx = next(sss.split(trainset.data, trainset_targets))
unused_subset = Subset(trainset, unused_idx)
used_subset = Subset(trainset, used_idx)
print(len(unused_subset))
print(len(used_subset))

# Prepare targets for used_subset
used_targets = [trainset_targets[i] for i in used_idx]
# Second split: 80% (train) and 20% (validation) of used_subset
sssplit = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, val_idx = next(sssplit.split(used_idx, used_targets))
train_data = Subset(trainset, [used_idx[i] for i in train_idx])
val_data = Subset(trainset, [used_idx[i] for i in val_idx])
print(len(train_data))
print(len(val_data))
# Out:
# 35000
# 15000
# 12000
# 3000

# %%
train_loader = DataLoader(train_data, batch_size=256, shuffle=True)
num_batches = len(train_loader)
print(num_batches)
# Out:
# 47

# %%
# load validation data
val_loader = DataLoader(val_data, batch_size=256, shuffle=False)

# %% [markdown]
# # Supervised Learning

# %% [markdown]
# 1 fold

# %% [markdown]
# Defining Model

# %%
# Load ResNet-50 without weights
baseline_model = resnet18(pretrained=False, num_classes=10)
# Replace the first 7x7 Conv with 3x3 Conv of stride 1
baseline_model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
# Remove the first MaxPooling2D layer (MaxPool2d)
baseline_model.maxpool = nn.Identity()  # Replace the first MaxPooling2D with an identity function
# Print model architecture
#print(baseline_model)
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
baseline_model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): Identity()
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()  # CrossEntropyLoss for multi-class classification

# %%
optimizer = optim.Adam(baseline_model.parameters(), lr=0.0008)
# ExponentialLR scheduler for learning rate decay
exp_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

# %%
num_epochs = 20
switch_epoch = 15
for epoch in range(num_epochs):
    for param_group in optimizer.param_groups:
        print(f'Start of Epoch {epoch+1}/{num_epochs}, Learning Rate: {param_group["lr"]:.6f}')
    baseline_model.train()  # Set the model to training mode
    running_loss = 0.0  # Initialize running loss, it is used to accumulate the total loss of all elements in a epoch
    counter = 1
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        # Forward pass
        outputs = baseline_model(inputs) #Compute predicted outputs by passing inputs to the model
        loss = criterion(outputs, labels) #Calculate the loss
      
        # Backward pass and optimization
        optimizer.zero_grad()   # Step 1: Clear old gradients
        loss.backward()         # Step 2: Compute new gradients, i.e Backward pass: Compute gradient of the loss with respect to model parameters
        optimizer.step()        # Step 3: Update model parameters
        running_loss += loss.item() * inputs.size(0)  # Accumulate loss. loss.item gives the avg loss of batch extrated from the loss tensor, input.size(0) gives the batch size, so * gives total loss in a batch
        #if counter % 10 == 0:
        #    print(f"Epoch [{epoch + 1}/{num_epochs}], Batch [{counter}/{num_batches}], Loss: {loss.item():.4f}")
        counter += 1

    epoch_loss = running_loss / len(train_loader.dataset)  # Running loss has total loss in an epoch, divide it by epoch size gives average loss in an epoch
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {epoch_loss:.4f}")
    # validate the model
    baseline_model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = baseline_model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        accuracy = 100 * correct / total
    print(f'Accuracy of the model on the 3000 validation images: {accuracy:.2f}%')
    
    #Training accuracy
    baseline_model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = baseline_model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        accuracy = 100 * correct / total
    print(f'Accuracy of the model on the 12000 train images: {accuracy:.2f}%')    
  
    if epoch+1 >= switch_epoch:
        exp_scheduler.gamma =  0.6   #10.0/(epoch+1) #
    exp_scheduler.step()  # Update learning rate scheduler
    #step_scheduler.step()
# Out:
# Start of Epoch 1/20, Learning Rate: 0.000800
# Epoch 1/20, Loss: 1.8792
# Accuracy of the model on the 3000 validation images: 35.13%
# Accuracy of the model on the 12000 train images: 35.31%
# Start of Epoch 2/20, Learning Rate: 0.000720
# Epoch 2/20, Loss: 1.5688
# Accuracy of the model on the 3000 validation images: 42.03%
# Accuracy of the model on the 12000 train images: 42.77%
# Start of Epoch 3/20, Learning Rate: 0.000648
# Epoch 3/20, Loss: 1.3975
# Accuracy of the model on the 3000 validation images: 49.10%
# Accuracy of the model on the 12000 train images: 51.67%
# Start of Epoch 4/20, Learning Rate: 0.000583
# Epoch 4/20, Loss: 1.2444
# Accuracy of the model on the 3000 validation images: 50.80%
# Accuracy of the model on the 12000 train images: 54.27%
# Start of Epoch 5/20, Learning Rate: 0.000525
# Epoch 5/20, Loss: 1.1251
# Accuracy of the model on the 3000 validation images: 55.50%
# Accuracy of the model on the 12000 train images: 57.59%
# Start of Epoch 6/20, Learning Rate: 0.000472
# Epoch 6/20, Loss: 1.0438
# Accuracy of the model on the 3000 validation images: 56.57%
# Accuracy of the model on the 12000 train images: 60.33%
# Start of Epoch 7/20, Learning Rate: 0.000425
# Epoch 7/20, Loss: 0.9491
# Accuracy of the model on the 3000 validation images: 59.67%
# Accuracy of the model on the 12000 train images: 65.17%
# Start of Epoch 8/20, Learning Rate: 0.000383
# Epoch 8/20, Loss: 0.8718
# Accuracy of the model on the 3000 validation images: 62.30%
# Accuracy of the model on the 12000 train images: 66.69%
# Start of Epoch 9/20, Learning Rate: 0.000344
# Epoch 9/20, Loss: 0.8330
# Accuracy of the model on the 3000 validation images: 60.53%
# Accuracy of the model on the 12000 train images: 65.47%
# Start of Epoch 10/20, Learning Rate: 0.000310
# Epoch 10/20, Loss: 0.7668
# Accuracy of the model on the 3000 validation images: 67.53%
# Accuracy of the model on the 12000 train images: 73.38%
# Start of Epoch 11/20, Learning Rate: 0.000279
# Epoch 11/20, Loss: 0.7352
# Accuracy of the model on the 3000 validation images: 67.63%
# Accuracy of the model on the 12000 train images: 74.52%
# Start of Epoch 12/20, Learning Rate: 0.000251
# Epoch 12/20, Loss: 0.6780
# Accuracy of the model on the 3000 validation images: 68.87%
# Accuracy of the model on the 12000 train images: 75.22%
# Start of Epoch 13/20, Learning Rate: 0.000226
# Epoch 13/20, Loss: 0.6480
# Accuracy of the model on the 3000 validation images: 66.13%
# Accuracy of the model on the 12000 train images: 73.12%
# Start of Epoch 14/20, Learning Rate: 0.000203
# Epoch 14/20, Loss: 0.6157
# Accuracy of the model on the 3000 validation images: 68.10%
# Accuracy of the model on the 12000 train images: 74.85%
# Start of Epoch 15/20, Learning Rate: 0.000183
# Epoch 15/20, Loss: 0.5894
# Accuracy of the model on the 3000 validation images: 71.83%
# Accuracy of the model on the 12000 train images: 79.08%
# Start of Epoch 16/20, Learning Rate: 0.000110
# Epoch 16/20, Loss: 0.5359
# Accuracy of the model on the 3000 validation images: 72.20%
# Accuracy of the model on the 12000 train images: 81.29%
# Start of Epoch 17/20, Learning Rate: 0.000066
# Epoch 17/20, Loss: 0.5094
# Accuracy of the model on the 3000 validation images: 73.53%
# Accuracy of the model on the 12000 train images: 81.96%
# Start of Epoch 18/20, Learning Rate: 0.000040
# Epoch 18/20, Loss: 0.4699
# Accuracy of the model on the 3000 validation images: 74.07%
# Accuracy of the model on the 12000 train images: 84.00%
# Start of Epoch 19/20, Learning Rate: 0.000024
# Epoch 19/20, Loss: 0.4575
# Accuracy of the model on the 3000 validation images: 74.90%
# Accuracy of the model on the 12000 train images: 84.92%
# Start of Epoch 20/20, Learning Rate: 0.000014
# Epoch 20/20, Loss: 0.4484
# Accuracy of the model on the 3000 validation images: 74.97%
# Accuracy of the model on the 12000 train images: 85.06%

# %% [markdown]
# 5 fold cross validation

# %%
trainset_targets = trainset.targets
# Stratified split to get 30% of the data
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
_, used_idx = next(sss.split(trainset.data, trainset_targets))
used_subset = Subset(trainset, used_idx)

# Prepare targets for used_subset
used_targets = [trainset_targets[i] for i in used_idx]

# Stratified K-Fold cross-validation
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
Loss = torch.zeros(5, 20)
Validation_accuracy = torch.zeros(5, 20)
Train_accuracy = torch.zeros(5, 20)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
for fold, (train_idx, val_idx) in enumerate(kf.split(np.zeros(len(used_targets)), used_targets)):
    print(f'Fold {fold + 1}')
    train_data = Subset(used_subset, train_idx)
    val_data = Subset(used_subset, val_idx)

    train_loader = DataLoader(train_data, batch_size=256, shuffle=True)
    val_loader = DataLoader(val_data, batch_size=256, shuffle=False)

    # Load ResNet-18 without pretrained weights
    model = resnet18(pretrained=False, num_classes=10)
    model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    model.maxpool = nn.Identity()
    model.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0008)
    exp_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)

    # Training
    num_epochs = 20
    switch_epoch = 15
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item() * inputs.size(0)
            
        epoch_loss = running_loss / len(train_loader.dataset)
        Loss[fold, epoch] = epoch_loss
        print(f'Epoch {epoch + 1}/{num_epochs}, Loss: {epoch_loss:.4f}')

        # Validation Accuracy
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            
        val_accuracy = 100 * correct / total
        Validation_accuracy[fold, epoch] = val_accuracy
        print(f'Validation Accuracy on fold {fold + 1}, Epoch {epoch + 1}/{num_epochs}: {val_accuracy:.2f}%')
        
        # Training Accuracy
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in train_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            
        Tr_accuracy = 100 * correct / total
        Train_accuracy[fold, epoch] = Tr_accuracy
        print(f'Training Accuracy on fold {fold + 1}, Epoch {epoch + 1}/{num_epochs}: {Tr_accuracy:.2f}%')
        
        if epoch + 1 >= switch_epoch:
            exp_scheduler.gamma = 0.6
        exp_scheduler.step()
        

# Calculate the mean along dim=0
average_loss = Loss.mean(dim=0)
average_validation_accuracy = Validation_accuracy.mean(dim=0)
average_train_accuracy = Train_accuracy.mean(dim=0)
# Out:
# Fold 1
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1/20, Loss: 1.8812
# Validation Accuracy on fold 1, Epoch 1/20: 36.73%
# Training Accuracy on fold 1, Epoch 1/20: 35.83%
# Epoch 2/20, Loss: 1.5524
# Validation Accuracy on fold 1, Epoch 2/20: 43.30%
# Training Accuracy on fold 1, Epoch 2/20: 43.82%
# Epoch 3/20, Loss: 1.3769
# Validation Accuracy on fold 1, Epoch 3/20: 43.20%
# Training Accuracy on fold 1, Epoch 3/20: 43.31%
# Epoch 4/20, Loss: 1.2290
# Validation Accuracy on fold 1, Epoch 4/20: 55.37%
# Training Accuracy on fold 1, Epoch 4/20: 56.57%
# Epoch 5/20, Loss: 1.1196
# Validation Accuracy on fold 1, Epoch 5/20: 56.27%
# Training Accuracy on fold 1, Epoch 5/20: 58.24%
# Epoch 6/20, Loss: 1.0277
# Validation Accuracy on fold 1, Epoch 6/20: 58.00%
# Training Accuracy on fold 1, Epoch 6/20: 60.42%
# Epoch 7/20, Loss: 0.9612
# Validation Accuracy on fold 1, Epoch 7/20: 64.40%
# Training Accuracy on fold 1, Epoch 7/20: 65.62%
# Epoch 8/20, Loss: 0.8983
# Validation Accuracy on fold 1, Epoch 8/20: 65.87%
# Training Accuracy on fold 1, Epoch 8/20: 68.54%
# Epoch 9/20, Loss: 0.8251
# Validation Accuracy on fold 1, Epoch 9/20: 67.83%
# Training Accuracy on fold 1, Epoch 9/20: 70.92%
# Epoch 10/20, Loss: 0.7754
# Validation Accuracy on fold 1, Epoch 10/20: 67.33%
# Training Accuracy on fold 1, Epoch 10/20: 68.97%
# Epoch 11/20, Loss: 0.7389
# Validation Accuracy on fold 1, Epoch 11/20: 68.23%
# Training Accuracy on fold 1, Epoch 11/20: 72.28%
# Epoch 12/20, Loss: 0.6991
# Validation Accuracy on fold 1, Epoch 12/20: 68.00%
# Training Accuracy on fold 1, Epoch 12/20: 71.85%
# Epoch 13/20, Loss: 0.6541
# Validation Accuracy on fold 1, Epoch 13/20: 73.27%
# Training Accuracy on fold 1, Epoch 13/20: 77.83%
# Epoch 14/20, Loss: 0.6261
# Validation Accuracy on fold 1, Epoch 14/20: 70.73%
# Training Accuracy on fold 1, Epoch 14/20: 75.32%
# Epoch 15/20, Loss: 0.5929
# Validation Accuracy on fold 1, Epoch 15/20: 74.10%
# Training Accuracy on fold 1, Epoch 15/20: 78.49%
# Epoch 16/20, Loss: 0.5631
# Validation Accuracy on fold 1, Epoch 16/20: 74.80%
# Training Accuracy on fold 1, Epoch 16/20: 80.90%
# Epoch 17/20, Loss: 0.5125
# Validation Accuracy on fold 1, Epoch 17/20: 76.33%
# Training Accuracy on fold 1, Epoch 17/20: 82.53%
# Epoch 18/20, Loss: 0.5006
# Validation Accuracy on fold 1, Epoch 18/20: 76.00%
# Training Accuracy on fold 1, Epoch 18/20: 83.77%
# Epoch 19/20, Loss: 0.4740
# Validation Accuracy on fold 1, Epoch 19/20: 76.50%
# Training Accuracy on fold 1, Epoch 19/20: 83.67%
# Epoch 20/20, Loss: 0.4631
# Validation Accuracy on fold 1, Epoch 20/20: 76.43%
# Training Accuracy on fold 1, Epoch 20/20: 84.37%
# Fold 2
# Epoch 1/20, Loss: 1.8958
# Validation Accuracy on fold 2, Epoch 1/20: 29.77%
# Training Accuracy on fold 2, Epoch 1/20: 31.33%
# Epoch 2/20, Loss: 1.5253
# Validation Accuracy on fold 2, Epoch 2/20: 41.53%
# Training Accuracy on fold 2, Epoch 2/20: 42.37%
# Epoch 3/20, Loss: 1.3865
# Validation Accuracy on fold 2, Epoch 3/20: 45.53%
# Training Accuracy on fold 2, Epoch 3/20: 46.28%
# Epoch 4/20, Loss: 1.2471
# Validation Accuracy on fold 2, Epoch 4/20: 52.37%
# Training Accuracy on fold 2, Epoch 4/20: 54.69%
# Epoch 5/20, Loss: 1.1269
# Validation Accuracy on fold 2, Epoch 5/20: 56.73%
# Training Accuracy on fold 2, Epoch 5/20: 58.91%
# Epoch 6/20, Loss: 1.0568
# Validation Accuracy on fold 2, Epoch 6/20: 59.83%
# Training Accuracy on fold 2, Epoch 6/20: 61.19%
# Epoch 7/20, Loss: 0.9611
# Validation Accuracy on fold 2, Epoch 7/20: 62.73%
# Training Accuracy on fold 2, Epoch 7/20: 66.91%
# Epoch 8/20, Loss: 0.8891
# Validation Accuracy on fold 2, Epoch 8/20: 61.70%
# Training Accuracy on fold 2, Epoch 8/20: 63.78%
# Epoch 9/20, Loss: 0.8370
# Validation Accuracy on fold 2, Epoch 9/20: 63.33%
# Training Accuracy on fold 2, Epoch 9/20: 66.70%
# Epoch 10/20, Loss: 0.7882
# Validation Accuracy on fold 2, Epoch 10/20: 67.30%
# Training Accuracy on fold 2, Epoch 10/20: 71.65%
# Epoch 11/20, Loss: 0.7432
# Validation Accuracy on fold 2, Epoch 11/20: 70.20%
# Training Accuracy on fold 2, Epoch 11/20: 75.08%
# Epoch 12/20, Loss: 0.6860
# Validation Accuracy on fold 2, Epoch 12/20: 70.03%
# Training Accuracy on fold 2, Epoch 12/20: 75.47%
# Epoch 13/20, Loss: 0.6502
# Validation Accuracy on fold 2, Epoch 13/20: 69.93%
# Training Accuracy on fold 2, Epoch 13/20: 75.78%
# Epoch 14/20, Loss: 0.6193
# Validation Accuracy on fold 2, Epoch 14/20: 72.30%
# Training Accuracy on fold 2, Epoch 14/20: 77.92%
# Epoch 15/20, Loss: 0.5881
# Validation Accuracy on fold 2, Epoch 15/20: 73.33%
# Training Accuracy on fold 2, Epoch 15/20: 80.09%
# Epoch 16/20, Loss: 0.5520
# Validation Accuracy on fold 2, Epoch 16/20: 73.77%
# Training Accuracy on fold 2, Epoch 16/20: 79.76%
# Epoch 17/20, Loss: 0.5009
# Validation Accuracy on fold 2, Epoch 17/20: 75.23%
# Training Accuracy on fold 2, Epoch 17/20: 83.10%
# Epoch 18/20, Loss: 0.4836
# Validation Accuracy on fold 2, Epoch 18/20: 75.63%
# Training Accuracy on fold 2, Epoch 18/20: 83.50%
# Epoch 19/20, Loss: 0.4594
# Validation Accuracy on fold 2, Epoch 19/20: 75.77%
# Training Accuracy on fold 2, Epoch 19/20: 84.13%
# Epoch 20/20, Loss: 0.4507
# Validation Accuracy on fold 2, Epoch 20/20: 76.00%
# Training Accuracy on fold 2, Epoch 20/20: 84.23%
# Fold 3
# Epoch 1/20, Loss: 1.9166
# Validation Accuracy on fold 3, Epoch 1/20: 35.80%
# Training Accuracy on fold 3, Epoch 1/20: 36.84%
# Epoch 2/20, Loss: 1.5871
# Validation Accuracy on fold 3, Epoch 2/20: 42.73%
# Training Accuracy on fold 3, Epoch 2/20: 43.14%
# Epoch 3/20, Loss: 1.3910
# Validation Accuracy on fold 3, Epoch 3/20: 49.27%
# Training Accuracy on fold 3, Epoch 3/20: 49.22%
# Epoch 4/20, Loss: 1.2524
# Validation Accuracy on fold 3, Epoch 4/20: 52.60%
# Training Accuracy on fold 3, Epoch 4/20: 54.51%
# Epoch 5/20, Loss: 1.1419
# Validation Accuracy on fold 3, Epoch 5/20: 55.70%
# Training Accuracy on fold 3, Epoch 5/20: 58.53%
# Epoch 6/20, Loss: 1.0444
# Validation Accuracy on fold 3, Epoch 6/20: 59.23%
# Training Accuracy on fold 3, Epoch 6/20: 61.98%
# Epoch 7/20, Loss: 0.9602
# Validation Accuracy on fold 3, Epoch 7/20: 62.20%
# Training Accuracy on fold 3, Epoch 7/20: 65.82%
# Epoch 8/20, Loss: 0.8973
# Validation Accuracy on fold 3, Epoch 8/20: 63.07%
# Training Accuracy on fold 3, Epoch 8/20: 66.98%
# Epoch 9/20, Loss: 0.8370
# Validation Accuracy on fold 3, Epoch 9/20: 62.90%
# Training Accuracy on fold 3, Epoch 9/20: 66.67%
# Epoch 10/20, Loss: 0.7856
# Validation Accuracy on fold 3, Epoch 10/20: 65.73%
# Training Accuracy on fold 3, Epoch 10/20: 69.88%
# Epoch 11/20, Loss: 0.7440
# Validation Accuracy on fold 3, Epoch 11/20: 68.50%
# Training Accuracy on fold 3, Epoch 11/20: 72.65%
# Epoch 12/20, Loss: 0.6971
# Validation Accuracy on fold 3, Epoch 12/20: 70.77%
# Training Accuracy on fold 3, Epoch 12/20: 76.25%
# Epoch 13/20, Loss: 0.6646
# Validation Accuracy on fold 3, Epoch 13/20: 72.23%
# Training Accuracy on fold 3, Epoch 13/20: 77.02%
# Epoch 14/20, Loss: 0.6239
# Validation Accuracy on fold 3, Epoch 14/20: 71.33%
# Training Accuracy on fold 3, Epoch 14/20: 77.46%
# Epoch 15/20, Loss: 0.5974
# Validation Accuracy on fold 3, Epoch 15/20: 72.07%
# Training Accuracy on fold 3, Epoch 15/20: 77.71%
# Epoch 16/20, Loss: 0.5603
# Validation Accuracy on fold 3, Epoch 16/20: 74.77%
# Training Accuracy on fold 3, Epoch 16/20: 81.53%
# Epoch 17/20, Loss: 0.5028
# Validation Accuracy on fold 3, Epoch 17/20: 75.97%
# Training Accuracy on fold 3, Epoch 17/20: 82.46%
# Epoch 18/20, Loss: 0.4882
# Validation Accuracy on fold 3, Epoch 18/20: 76.40%
# Training Accuracy on fold 3, Epoch 18/20: 84.21%
# Epoch 19/20, Loss: 0.4715
# Validation Accuracy on fold 3, Epoch 19/20: 76.10%
# Training Accuracy on fold 3, Epoch 19/20: 84.38%
# Epoch 20/20, Loss: 0.4640
# Validation Accuracy on fold 3, Epoch 20/20: 76.80%
# Training Accuracy on fold 3, Epoch 20/20: 84.66%
# Fold 4
# Epoch 1/20, Loss: 1.8656
# Validation Accuracy on fold 4, Epoch 1/20: 34.93%
# Training Accuracy on fold 4, Epoch 1/20: 35.37%
# Epoch 2/20, Loss: 1.5130
# Validation Accuracy on fold 4, Epoch 2/20: 49.17%
# Training Accuracy on fold 4, Epoch 2/20: 48.76%
# Epoch 3/20, Loss: 1.3506
# Validation Accuracy on fold 4, Epoch 3/20: 49.50%
# Training Accuracy on fold 4, Epoch 3/20: 49.99%
# Epoch 4/20, Loss: 1.1949
# Validation Accuracy on fold 4, Epoch 4/20: 53.40%
# Training Accuracy on fold 4, Epoch 4/20: 54.19%
# Epoch 5/20, Loss: 1.1124
# Validation Accuracy on fold 4, Epoch 5/20: 60.63%
# Training Accuracy on fold 4, Epoch 5/20: 62.57%
# Epoch 6/20, Loss: 1.0296
# Validation Accuracy on fold 4, Epoch 6/20: 63.77%
# Training Accuracy on fold 4, Epoch 6/20: 66.11%
# Epoch 7/20, Loss: 0.9440
# Validation Accuracy on fold 4, Epoch 7/20: 63.77%
# Training Accuracy on fold 4, Epoch 7/20: 66.41%
# Epoch 8/20, Loss: 0.8833
# Validation Accuracy on fold 4, Epoch 8/20: 64.50%
# Training Accuracy on fold 4, Epoch 8/20: 68.20%
# Epoch 9/20, Loss: 0.8253
# Validation Accuracy on fold 4, Epoch 9/20: 68.93%
# Training Accuracy on fold 4, Epoch 9/20: 71.36%
# Epoch 10/20, Loss: 0.7650
# Validation Accuracy on fold 4, Epoch 10/20: 67.90%
# Training Accuracy on fold 4, Epoch 10/20: 71.12%
# Epoch 11/20, Loss: 0.7305
# Validation Accuracy on fold 4, Epoch 11/20: 69.63%
# Training Accuracy on fold 4, Epoch 11/20: 73.82%
# Epoch 12/20, Loss: 0.6925
# Validation Accuracy on fold 4, Epoch 12/20: 69.23%
# Training Accuracy on fold 4, Epoch 12/20: 73.50%
# Epoch 13/20, Loss: 0.6552
# Validation Accuracy on fold 4, Epoch 13/20: 70.77%
# Training Accuracy on fold 4, Epoch 13/20: 76.07%
# Epoch 14/20, Loss: 0.6182
# Validation Accuracy on fold 4, Epoch 14/20: 71.33%
# Training Accuracy on fold 4, Epoch 14/20: 78.31%
# Epoch 15/20, Loss: 0.5946
# Validation Accuracy on fold 4, Epoch 15/20: 72.27%
# Training Accuracy on fold 4, Epoch 15/20: 78.12%
# Epoch 16/20, Loss: 0.5402
# Validation Accuracy on fold 4, Epoch 16/20: 74.30%
# Training Accuracy on fold 4, Epoch 16/20: 81.09%
# Epoch 17/20, Loss: 0.5052
# Validation Accuracy on fold 4, Epoch 17/20: 76.10%
# Training Accuracy on fold 4, Epoch 17/20: 82.80%
# Epoch 18/20, Loss: 0.4849
# Validation Accuracy on fold 4, Epoch 18/20: 76.47%
# Training Accuracy on fold 4, Epoch 18/20: 83.50%
# Epoch 19/20, Loss: 0.4711
# Validation Accuracy on fold 4, Epoch 19/20: 76.67%
# Training Accuracy on fold 4, Epoch 19/20: 84.36%
# Epoch 20/20, Loss: 0.4566
# Validation Accuracy on fold 4, Epoch 20/20: 76.87%
# Training Accuracy on fold 4, Epoch 20/20: 84.75%
# Fold 5
# Epoch 1/20, Loss: 1.8874
# Validation Accuracy on fold 5, Epoch 1/20: 35.43%
# Training Accuracy on fold 5, Epoch 1/20: 36.47%
# Epoch 2/20, Loss: 1.5730
# Validation Accuracy on fold 5, Epoch 2/20: 40.70%
# Training Accuracy on fold 5, Epoch 2/20: 42.70%
# Epoch 3/20, Loss: 1.3835
# Validation Accuracy on fold 5, Epoch 3/20: 50.37%
# Training Accuracy on fold 5, Epoch 3/20: 50.99%
# Epoch 4/20, Loss: 1.2406
# Validation Accuracy on fold 5, Epoch 4/20: 46.57%
# Training Accuracy on fold 5, Epoch 4/20: 48.20%
# Epoch 5/20, Loss: 1.1475
# Validation Accuracy on fold 5, Epoch 5/20: 54.97%
# Training Accuracy on fold 5, Epoch 5/20: 56.98%
# Epoch 6/20, Loss: 1.0428
# Validation Accuracy on fold 5, Epoch 6/20: 60.07%
# Training Accuracy on fold 5, Epoch 6/20: 63.92%
# Epoch 7/20, Loss: 0.9705
# Validation Accuracy on fold 5, Epoch 7/20: 58.60%
# Training Accuracy on fold 5, Epoch 7/20: 61.60%
# Epoch 8/20, Loss: 0.8845
# Validation Accuracy on fold 5, Epoch 8/20: 62.77%
# Training Accuracy on fold 5, Epoch 8/20: 67.16%
# Epoch 9/20, Loss: 0.8354
# Validation Accuracy on fold 5, Epoch 9/20: 61.63%
# Training Accuracy on fold 5, Epoch 9/20: 66.10%
# Epoch 10/20, Loss: 0.7871
# Validation Accuracy on fold 5, Epoch 10/20: 66.67%
# Training Accuracy on fold 5, Epoch 10/20: 70.62%
# Epoch 11/20, Loss: 0.7318
# Validation Accuracy on fold 5, Epoch 11/20: 68.53%
# Training Accuracy on fold 5, Epoch 11/20: 72.59%
# Epoch 12/20, Loss: 0.7103
# Validation Accuracy on fold 5, Epoch 12/20: 70.07%
# Training Accuracy on fold 5, Epoch 12/20: 74.87%
# Epoch 13/20, Loss: 0.6554
# Validation Accuracy on fold 5, Epoch 13/20: 70.67%
# Training Accuracy on fold 5, Epoch 13/20: 76.23%
# Epoch 14/20, Loss: 0.6279
# Validation Accuracy on fold 5, Epoch 14/20: 70.13%
# Training Accuracy on fold 5, Epoch 14/20: 77.66%
# Epoch 15/20, Loss: 0.5991
# Validation Accuracy on fold 5, Epoch 15/20: 70.43%
# Training Accuracy on fold 5, Epoch 15/20: 77.45%
# Epoch 16/20, Loss: 0.5454
# Validation Accuracy on fold 5, Epoch 16/20: 73.00%
# Training Accuracy on fold 5, Epoch 16/20: 80.75%
# Epoch 17/20, Loss: 0.5199
# Validation Accuracy on fold 5, Epoch 17/20: 75.57%
# Training Accuracy on fold 5, Epoch 17/20: 82.27%
# Epoch 18/20, Loss: 0.5073
# Validation Accuracy on fold 5, Epoch 18/20: 74.37%
# Training Accuracy on fold 5, Epoch 18/20: 82.96%
# Epoch 19/20, Loss: 0.4759
# Validation Accuracy on fold 5, Epoch 19/20: 75.33%
# Training Accuracy on fold 5, Epoch 19/20: 84.41%
# Epoch 20/20, Loss: 0.4717
# Validation Accuracy on fold 5, Epoch 20/20: 75.77%
# Training Accuracy on fold 5, Epoch 20/20: 84.53%

# %% [markdown]
# printing the loss, val_acc and train_acc

# %%
print(f'avg loss = {average_loss}')
print(f'avg validation accuracy: {average_validation_accuracy}')
print(f'avg train accuracy = {average_train_accuracy}')
# Out:
# avg loss = tensor([1.8893, 1.5502, 1.3777, 1.2328, 1.1297, 1.0403, 0.9594, 0.8905, 0.8320,
#         0.7802, 0.7377, 0.6970, 0.6559, 0.6231, 0.5944, 0.5522, 0.5083, 0.4929,
#         0.4704, 0.4612])
# avg validation accuracy: tensor([34.5333, 43.4867, 47.5733, 52.0600, 56.8600, 60.1800, 62.3400, 63.5800,
#         64.9267, 66.9867, 69.0200, 69.6200, 71.3733, 71.1667, 72.4400, 74.1267,
#         75.8400, 75.7733, 76.0733, 76.3733])
# avg train accuracy = tensor([35.1683, 44.1567, 47.9583, 53.6317, 59.0450, 62.7233, 65.2717, 66.9333,
#         68.3500, 70.4500, 73.2833, 74.3867, 76.5867, 77.3333, 78.3717, 80.8050,
#         82.6300, 83.5867, 84.1883, 84.5083])

# %% [markdown]
# plotting the loss, val_acc and train_acc

# %%
# Epoch numbers from 1 to 20
epochs = list(range(1, 21))

# Create the figure and subplots
fig, axes = plt.subplots(3, 1, figsize=(10, 18))

# Plot Average Loss
axes[0].plot(epochs, average_loss, label='Average Loss', marker='o')
axes[0].set_title('Average Loss over Epochs')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Average Loss')
axes[0].legend()
axes[0].grid(True)  # Add grid

# Plot Validation Accuracy
axes[1].plot(epochs, average_validation_accuracy, label='Validation Accuracy', marker='o')
axes[1].set_title('Validation Accuracy over Epochs')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Validation Accuracy')
axes[1].legend()
axes[1].grid(True)  # Add grid

# Plot Training Accuracy
axes[2].plot(epochs, average_train_accuracy, label='Training Accuracy', marker='o')
axes[2].set_title('Training Accuracy over Epochs')
axes[2].set_xlabel('Epoch')
axes[2].set_ylabel('Training Accuracy')
axes[2].legend()
axes[2].grid(True)  # Add grid

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()
